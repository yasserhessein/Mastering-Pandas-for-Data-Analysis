# %% [markdown]
# # Read HTML
# https://en.wikipedia.org/wiki/Amazon_(company)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/Amazon_(company)')

# %%
df
# Out:
# [                                     0  \
#  0         Logo used since January 2000
#  1   Amazon's headquarters, the Doppler
#  2                           Trade name
#  3                             Formerly
#  4                         Company type
#  5                            Traded as
#  6                                 ISIN
#  7                             Industry
#  8                              Founded
#  9                              Founder
#  10                        Headquarters
#  11                         Area served
#  12                          Key people
#  13                            Products
#  14                            Services
#  15                             Revenue
#  16                    Operating income
#  17                          Net income
#  18                        Total assets
#  19                        Total equity
#  20                               Owner
#  21                 Number of employees
# ...

# %%
df[2]
# Out:
#       Region               Country    Domain name           Since  \
# 0     Africa                 Egypt      amazon.eg  September 2021
# 1   Americas                Brazil  amazon.com.br   December 2012
# 2   Americas                Canada      amazon.ca       June 2002
# 3   Americas                Mexico  amazon.com.mx     August 2013
# 4   Americas         United States     amazon.com       July 1995
# 5       Asia                 China      amazon.cn  September 2004
# 6       Asia                 India      amazon.in       June 2013
# 7       Asia                 Japan   amazon.co.jp   November 2000
# 8       Asia          Saudi Arabia      amazon.sa       June 2020
# 9       Asia             Singapore      amazon.sg       July 2017
# 10      Asia                Turkey  amazon.com.tr  September 2018
# 11      Asia  United Arab Emirates      amazon.ae        May 2019
# 12    Europe               Belgium  amazon.com.be    October 2022
# ...
