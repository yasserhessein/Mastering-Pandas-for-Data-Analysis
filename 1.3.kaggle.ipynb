# %%
#{"username":"ammaryasirh","key":"1f05c41f7f7a8e5d5fdda04f84668962"}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#{"username":"ammaryasirh","key":"c08cf5e20629ed7011ff1d7c85bdf9f8"}

# %%
#!pip install opendatasets

# %% [markdown]
# https://www.kaggle.com/datasets/rafsunahmad/global-yearly-temperature-change-in-the-surface?select=Annual+Surface+Temperature+Change.csv

# %%
import opendatasets as od

od.download(
    "https://www.kaggle.com/datasets/elvinrustam/electronics-dataset?select=ElectronicsData.csv")
# Out:
# Skipping, found downloaded files in ".\electronics-dataset" (use force=True to force download)

# %%
import pandas as pd
#encoding='latin1
df = pd.read_csv("ElectronicsData.csv")
df
# Out:
#                Sub Category     Price     Discount  \
# 0                 Batteries   $20.99   No Discount
# 1                 Batteries   $20.99   No Discount
# 2                 Batteries   $20.99   No Discount
# 3                 Batteries   $18.99   No Discount
# 4                 Batteries   $14.99   No Discount
# ..                      ...       ...          ...
# 638  Video Games & Consoles  $949.99   No Discount
# 639  Video Games & Consoles  $449.99   No Discount
# 640  Video Games & Consoles  $199.99   No Discount
# 641  Video Games & Consoles   $49.97   No Discount
# 642  Video Games & Consoles  $599.99   No Discount
#
#                                              Rating  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4    Rated 4.8 out of 5 stars based on 125 reviews.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sub Category  643 non-null    object
#  1   Price         642 non-null    object
#  2   Discount      641 non-null    object
#  3   Rating        634 non-null    object
#  4   Title         643 non-null    object
#  5   Currency      642 non-null    object
#  6   Feature       642 non-null    object
# dtypes: object(7)
# memory usage: 35.3+ KB
